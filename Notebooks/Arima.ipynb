# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# %%
# Load the data from CSV
data1 = pd.read_csv('/content/morocco 2021-01-01 to 2021-12-31.csv', usecols=['datetime', 'temp'])
data2 = pd.read_csv('/content/morocco 2022-01-01 to 2022-12-31.csv', usecols=['datetime', 'temp'])
data3 = pd.read_csv('/content/morocco 2023-01-01 to 2023-05-01.csv', usecols=['datetime', 'temp'])

data = pd.concat([data1, data2, data3], axis=0)
data.reset_index(drop=True, inplace=True)
data
# Out:
#        datetime  temp
# 0    2021-01-01  50.1
# 1    2021-01-02  51.9
# 2    2021-01-03  48.3
# 3    2021-01-04  46.9
# 4    2021-01-05  49.7
# ..          ...   ...
# 846  2023-04-27  72.9
# 847  2023-04-28  68.2
# 848  2023-04-29  69.8
# 849  2023-04-30  65.3
# 850  2023-05-01  65.6
#
# [851 rows x 2 columns]

# %%
# Convert datetime column to datetime object
data['datetime'] = pd.to_datetime(data['datetime'])
data.set_index('datetime', inplace=True)

# %%
len(data)*0.8
# Out:
# 680.8000000000001

# %%
# Resample the data to daily frequency and fill missing values (if any)
data = data.resample('D').mean().fillna(method='ffill')

# %%
# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data[:train_size], data[train_size:]

# %%
# Fit ARIMA model
# NO multivariate time series forecasting

model = ARIMA(train['temp'], order=(150,1,0))
model_fit = model.fit()

forecast = model_fit.forecast(steps=len(test))
forecast_index = pd.date_range(start=test.index[0], periods=len(test), freq='D')
forecast_df = pd.DataFrame(forecast, index=forecast_index, columns=['temp'])

# %%
# Plotting
plt.figure(figsize=(10,6))
plt.plot(train.index, train['temp'], label='Training Data')
plt.plot(test.index, test['temp'], label='Test Data')
plt.plot(test.index, forecast, label='ARIMA Forecast')
plt.title('ARIMA Weather Forecasting')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
# Load the data from CSV
data1 = pd.read_csv('/content/morocco 2021-01-01 to 2021-12-31.csv', usecols=['datetime', 'precip'])
data2 = pd.read_csv('/content/morocco 2022-01-01 to 2022-12-31.csv', usecols=['datetime', 'precip'])
data3 = pd.read_csv('/content/morocco 2023-01-01 to 2023-05-01.csv', usecols=['datetime', 'precip'])

data2 = pd.concat([data1, data2, data3], axis=0)
data2.reset_index(drop=True, inplace=True)
data2
# Out:
#        datetime  precip
# 0    2021-01-01   0.173
# 1    2021-01-02   0.346
# 2    2021-01-03   0.012
# 3    2021-01-04   0.004
# 4    2021-01-05   0.669
# ..          ...     ...
# 846  2023-04-27   0.000
# 847  2023-04-28   0.000
# 848  2023-04-29   0.000
# 849  2023-04-30   0.000
# 850  2023-05-01   0.000
#
# [851 rows x 2 columns]

# %%
# Convert datetime column to datetime object
data2['datetime'] = pd.to_datetime(data2['datetime'])
data2.set_index('datetime', inplace=True)

# %%
# Resample the data to daily frequency and fill missing values (if any)
data2 = data2.resample('D').mean().fillna(method='ffill')

# %%
# Split data into train and test sets
train_size = int(len(data2) * 0.8)
train, test = data2[:train_size], data2[train_size:]

# %%
# Fit ARIMA model
# NO multivariate time series forecasting

model = ARIMA(train['precip'], order=(150,1,0))
model_fit = model.fit()

forecast = model_fit.forecast(steps=len(test))
forecast_index = pd.date_range(start=test.index[0], periods=len(test), freq='D')
forecast_df = pd.DataFrame(forecast, index=forecast_index, columns=['precip'])

# %%
# Plotting
plt.figure(figsize=(10,6))
plt.plot(train.index, train['precip'], label='Training Data')
plt.plot(test.index, test['precip'], label='Test Data')
plt.plot(test.index, forecast, label='ARIMA Forecast')
plt.title('ARIMA Weather Forecasting')
plt.xlabel('Date')
plt.ylabel('Précipitation')
plt.legend()
plt.show()

# %%
# Load the data from CSV
data1 = pd.read_csv('/content/morocco 2021-01-01 to 2021-12-31.csv', usecols=['datetime', 'humidity'])
data2 = pd.read_csv('/content/morocco 2022-01-01 to 2022-12-31.csv', usecols=['datetime', 'humidity'])
data3 = pd.read_csv('/content/morocco 2023-01-01 to 2023-05-01.csv', usecols=['datetime', 'humidity'])

data = pd.concat([data1, data2, data3], axis=0)
data.reset_index(drop=True, inplace=True)
data

# %%
# Convert datetime column to datetime object
data['datetime'] = pd.to_datetime(data['datetime'])
data.set_index('datetime', inplace=True)

# %%
# Resample the data to daily frequency and fill missing values (if any)
data = data.resample('D').mean().fillna(method='ffill')

# %%
# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data[:train_size], data[train_size:]

# %%
# Fit ARIMA model
# NO multivariate time series forecasting

model = ARIMA(train['humidity'], order=(150,1,0))
model_fit = model.fit()

forecast = model_fit.forecast(steps=len(test))
forecast_index = pd.date_range(start=test.index[0], periods=len(test), freq='D')
forecast_df = pd.DataFrame(forecast, index=forecast_index, columns=['temp'])

# %%
# Plotting
plt.figure(figsize=(10,6))
plt.plot(train.index, train['humidity'], label='Training Data')
plt.plot(test.index, test['humidity'], label='Test Data')
plt.plot(test.index, forecast, label='ARIMA Forecast')
plt.title('ARIMA Weather Forecasting')
plt.xlabel('Date')
plt.ylabel('humidity')
plt.legend()
plt.show()
